# %%
# !pip install sentencepiece
# !pip install transformers
# !pip install seqeval
# !pip install datasets
# !pip install ruamel.yaml
# !pip install ray
# !pip install -Ur requirements.txt
# !pip install massive.py
# !pip install googletrans==3.1.0a0
# !pip install googledrivedownloader
# Out:
# Requirement already satisfied: sentencepiece in ./venv/lib/python3.9/site-packages (0.1.96)
# WARNING: You are using pip version 21.3.1; however, version 22.2.1 is available.
# You should consider upgrading via the '/Users/molion/Documents/uj/IV/nlp_with_dl/project/NLP_Project/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: transformers in ./venv/lib/python3.9/site-packages (4.20.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in ./venv/lib/python3.9/site-packages (from transformers) (0.12.1)
# Requirement already satisfied: filelock in ./venv/lib/python3.9/site-packages (from transformers) (3.7.1)
# Requirement already satisfied: numpy>=1.17 in ./venv/lib/python3.9/site-packages (from transformers) (1.23.0)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.9/site-packages (from transformers) (21.3)
# Requirement already satisfied: requests in ./venv/lib/python3.9/site-packages (from transformers) (2.28.0)
# Requirement already satisfied: tqdm>=4.27 in ./venv/lib/python3.9/site-packages (from transformers) (4.64.0)
# Requirement already satisfied: regex!=2019.12.17 in ./venv/lib/python3.9/site-packages (from transformers) (2022.6.2)
# Requirement already satisfied: pyyaml>=5.1 in ./venv/lib/python3.9/site-packages (from transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in ./venv/lib/python3.9/site-packages (from transformers) (0.8.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./venv/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./venv/lib/python3.9/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.9/site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./venv/lib/python3.9/site-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./venv/lib/python3.9/site-packages (from requests->transformers) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.9/site-packages (from requests->transformers) (2022.6.15)
# WARNING: You are using pip version 21.3.1; however, version 22.2.1 is available.
# You should consider upgrading via the '/Users/molion/Documents/uj/IV/nlp_with_dl/project/NLP_Project/venv/bin/python -m pip install --upgrade pip' command.
# Collecting seqeval
#   Using cached seqeval-1.2.2-py3-none-any.whl
# Requirement already satisfied: numpy>=1.14.0 in ./venv/lib/python3.9/site-packages (from seqeval) (1.23.0)
# Collecting scikit-learn>=0.21.3
#   Using cached scikit_learn-1.1.1-cp39-cp39-macosx_10_13_x86_64.whl (8.6 MB)
# Collecting scipy>=1.3.2
#   Downloading scipy-1.9.0-cp39-cp39-macosx_12_0_universal2.macosx_10_9_x86_64.whl (58.4 MB)
#      |████████████████████████████████| 58.4 MB 9.7 MB/s
# Collecting joblib>=1.0.0
#   Using cached joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, seqeval
# Successfully installed joblib-1.1.0 scikit-learn-1.1.1 scipy-1.9.0 seqeval-1.2.2 threadpoolctl-3.1.0
# WARNING: You are using pip version 21.3.1; however, version 22.2.1 is available.
# You should consider upgrading via the '/Users/molion/Documents/uj/IV/nlp_with_dl/project/NLP_Project/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: datasets in ./venv/lib/python3.9/site-packages (2.3.2)
# Requirement already satisfied: xxhash in ./venv/lib/python3.9/site-packages (from datasets) (3.0.0)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in ./venv/lib/python3.9/site-packages (from datasets) (2022.5.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in ./venv/lib/python3.9/site-packages (from datasets) (0.8.1)
# Requirement already satisfied: numpy>=1.17 in ./venv/lib/python3.9/site-packages (from datasets) (1.23.0)
# Requirement already satisfied: pandas in ./venv/lib/python3.9/site-packages (from datasets) (1.4.2)
# Requirement already satisfied: aiohttp in ./venv/lib/python3.9/site-packages (from datasets) (3.8.1)
# Requirement already satisfied: tqdm>=4.62.1 in ./venv/lib/python3.9/site-packages (from datasets) (4.64.0)
# Requirement already satisfied: dill<0.3.6 in ./venv/lib/python3.9/site-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: pyarrow>=6.0.0 in ./venv/lib/python3.9/site-packages (from datasets) (8.0.0)
# Requirement already satisfied: packaging in ./venv/lib/python3.9/site-packages (from datasets) (21.3)
# Requirement already satisfied: multiprocess in ./venv/lib/python3.9/site-packages (from datasets) (0.70.13)
# Requirement already satisfied: responses<0.19 in ./venv/lib/python3.9/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: requests>=2.19.0 in ./venv/lib/python3.9/site-packages (from datasets) (2.28.0)
# Requirement already satisfied: pyyaml>=5.1 in ./venv/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./venv/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.2.0)
# Requirement already satisfied: filelock in ./venv/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./venv/lib/python3.9/site-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (1.26.9)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.9/site-packages (from aiohttp->datasets) (1.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./venv/lib/python3.9/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.9/site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.9/site-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./venv/lib/python3.9/site-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.9/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./venv/lib/python3.9/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.9/site-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# WARNING: You are using pip version 21.3.1; however, version 22.2.1 is available.
# You should consider upgrading via the '/Users/molion/Documents/uj/IV/nlp_with_dl/project/NLP_Project/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: ruamel.yaml in ./venv/lib/python3.9/site-packages (0.17.21)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in ./venv/lib/python3.9/site-packages (from ruamel.yaml) (0.2.6)
# WARNING: You are using pip version 21.3.1; however, version 22.2.1 is available.
# You should consider upgrading via the '/Users/molion/Documents/uj/IV/nlp_with_dl/project/NLP_Project/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: ray in ./venv/lib/python3.9/site-packages (1.13.0)
# Requirement already satisfied: aiosignal in ./venv/lib/python3.9/site-packages (from ray) (1.2.0)
# Requirement already satisfied: numpy>=1.19.3 in ./venv/lib/python3.9/site-packages (from ray) (1.23.0)
# Requirement already satisfied: attrs in ./venv/lib/python3.9/site-packages (from ray) (21.4.0)
# Requirement already satisfied: protobuf<4.0.0,>=3.15.3 in ./venv/lib/python3.9/site-packages (from ray) (3.20.1)
# Requirement already satisfied: jsonschema in ./venv/lib/python3.9/site-packages (from ray) (4.6.0)
# Requirement already satisfied: filelock in ./venv/lib/python3.9/site-packages (from ray) (3.7.1)
# Requirement already satisfied: requests in ./venv/lib/python3.9/site-packages (from ray) (2.28.0)
# Requirement already satisfied: virtualenv in ./venv/lib/python3.9/site-packages (from ray) (20.14.1)
# Requirement already satisfied: pyyaml in ./venv/lib/python3.9/site-packages (from ray) (6.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./venv/lib/python3.9/site-packages (from ray) (1.0.4)
# Requirement already satisfied: frozenlist in ./venv/lib/python3.9/site-packages (from ray) (1.3.0)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in ./venv/lib/python3.9/site-packages (from ray) (1.43.0)
# Requirement already satisfied: click<=8.0.4,>=7.0 in ./venv/lib/python3.9/site-packages (from ray) (8.0.4)
# Requirement already satisfied: six>=1.5.2 in ./venv/lib/python3.9/site-packages (from grpcio<=1.43.0,>=1.28.1->ray) (1.16.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./venv/lib/python3.9/site-packages (from jsonschema->ray) (0.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./venv/lib/python3.9/site-packages (from requests->ray) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./venv/lib/python3.9/site-packages (from requests->ray) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.9/site-packages (from requests->ray) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.9/site-packages (from requests->ray) (2.10)
# Requirement already satisfied: platformdirs<3,>=2 in ./venv/lib/python3.9/site-packages (from virtualenv->ray) (2.5.2)
# Requirement already satisfied: distlib<1,>=0.3.1 in ./venv/lib/python3.9/site-packages (from virtualenv->ray) (0.3.4)
# WARNING: You are using pip version 21.3.1; however, version 22.2.1 is available.
# You should consider upgrading via the '/Users/molion/Documents/uj/IV/nlp_with_dl/project/NLP_Project/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: ray[tune] in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (1.13.0)
# Requirement already satisfied: filelock in ./venv/lib/python3.9/site-packages (from ray[tune]->-r requirements.txt (line 1)) (3.7.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./venv/lib/python3.9/site-packages (from ray[tune]->-r requirements.txt (line 1)) (1.0.4)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in ./venv/lib/python3.9/site-packages (from ray[tune]->-r requirements.txt (line 1)) (1.43.0)
# Requirement already satisfied: attrs in ./venv/lib/python3.9/site-packages (from ray[tune]->-r requirements.txt (line 1)) (21.4.0)
# Requirement already satisfied: jsonschema in ./venv/lib/python3.9/site-packages (from ray[tune]->-r requirements.txt (line 1)) (4.6.0)
# Requirement already satisfied: requests in ./venv/lib/python3.9/site-packages (from ray[tune]->-r requirements.txt (line 1)) (2.28.0)
# Requirement already satisfied: numpy>=1.19.3 in ./venv/lib/python3.9/site-packages (from ray[tune]->-r requirements.txt (line 1)) (1.23.0)
# Requirement already satisfied: protobuf<4.0.0,>=3.15.3 in ./venv/lib/python3.9/site-packages (from ray[tune]->-r requirements.txt (line 1)) (3.20.1)
# Requirement already satisfied: click<=8.0.4,>=7.0 in ./venv/lib/python3.9/site-packages (from ray[tune]->-r requirements.txt (line 1)) (8.0.4)
# Requirement already satisfied: virtualenv in ./venv/lib/python3.9/site-packages (from ray[tune]->-r requirements.txt (line 1)) (20.14.1)
# Requirement already satisfied: pyyaml in ./venv/lib/python3.9/site-packages (from ray[tune]->-r requirements.txt (line 1)) (6.0)
# Requirement already satisfied: frozenlist in ./venv/lib/python3.9/site-packages (from ray[tune]->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: aiosignal in ./venv/lib/python3.9/site-packages (from ray[tune]->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: tabulate in ./venv/lib/python3.9/site-packages (from ray[tune]->-r requirements.txt (line 1)) (0.8.10)
# Requirement already satisfied: pandas in ./venv/lib/python3.9/site-packages (from ray[tune]->-r requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: tensorboardX>=1.9 in ./venv/lib/python3.9/site-packages (from ray[tune]->-r requirements.txt (line 1)) (2.5.1)
# Requirement already satisfied: six>=1.5.2 in ./venv/lib/python3.9/site-packages (from grpcio<=1.43.0,>=1.28.1->ray[tune]->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./venv/lib/python3.9/site-packages (from jsonschema->ray[tune]->-r requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./venv/lib/python3.9/site-packages (from pandas->ray[tune]->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.9/site-packages (from pandas->ray[tune]->-r requirements.txt (line 1)) (2022.1)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.9/site-packages (from requests->ray[tune]->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.9/site-packages (from requests->ray[tune]->-r requirements.txt (line 1)) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./venv/lib/python3.9/site-packages (from requests->ray[tune]->-r requirements.txt (line 1)) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./venv/lib/python3.9/site-packages (from requests->ray[tune]->-r requirements.txt (line 1)) (1.26.9)
# Requirement already satisfied: platformdirs<3,>=2 in ./venv/lib/python3.9/site-packages (from virtualenv->ray[tune]->-r requirements.txt (line 1)) (2.5.2)
# Requirement already satisfied: distlib<1,>=0.3.1 in ./venv/lib/python3.9/site-packages (from virtualenv->ray[tune]->-r requirements.txt (line 1)) (0.3.4)
# WARNING: You are using pip version 21.3.1; however, version 22.2.1 is available.
# You should consider upgrading via the '/Users/molion/Documents/uj/IV/nlp_with_dl/project/NLP_Project/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: massive.py in ./venv/lib/python3.9/site-packages (0.5.3)
# Requirement already satisfied: emoji in ./venv/lib/python3.9/site-packages (from massive.py) (1.7.0)
# WARNING: You are using pip version 21.3.1; however, version 22.2.1 is available.
# You should consider upgrading via the '/Users/molion/Documents/uj/IV/nlp_with_dl/project/NLP_Project/venv/bin/python -m pip install --upgrade pip' command.
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: httpx==0.13.3 in ./venv/lib/python3.9/site-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: certifi in ./venv/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2022.6.15)
# Requirement already satisfied: httpcore==0.9.* in ./venv/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: sniffio in ./venv/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.2.0)
# Requirement already satisfied: chardet==3.* in ./venv/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: idna==2.* in ./venv/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: hstspreload in ./venv/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2021.12.1)
# Requirement already satisfied: rfc3986<2,>=1.3 in ./venv/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.5.0)
# Requirement already satisfied: h2==3.* in ./venv/lib/python3.9/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: h11<0.10,>=0.8 in ./venv/lib/python3.9/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: hpack<4,>=3.0 in ./venv/lib/python3.9/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in ./venv/lib/python3.9/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16367 sha256=fba29c096e2c01604a11bc850d75a307da5b7b7506f013566a27b11a3617441a
#   Stored in directory: /Users/molion/Library/Caches/pip/wheels/ae/e1/6c/5137bc3f35aa130deea71575e165cc4f4f0680a88f3d90a636
# Successfully built googletrans
# Installing collected packages: googletrans
#   Attempting uninstall: googletrans
#     Found existing installation: googletrans 3.0.0
#     Uninstalling googletrans-3.0.0:
#       Successfully uninstalled googletrans-3.0.0
# Successfully installed googletrans-3.1.0a0
# WARNING: You are using pip version 21.3.1; however, version 22.2.1 is available.
# You should consider upgrading via the '/Users/molion/Documents/uj/IV/nlp_with_dl/project/NLP_Project/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: googledrivedownloader in ./venv/lib/python3.9/site-packages (0.4)
# WARNING: You are using pip version 21.3.1; however, version 22.2.1 is available.
# You should consider upgrading via the '/Users/molion/Documents/uj/IV/nlp_with_dl/project/NLP_Project/venv/bin/python -m pip install --upgrade pip' command.
